# %%
import mlflow

if __name__ == "__main__":
    # create a new mlflow experiment
    experiment_id = mlflow.create_experiment(
        name="testing_mlflow1_George_DEPI_R4_s2",
        artifact_location="testing_mlflow1_artifacts",
        tags={"env": "dev", "version": "1.0.0"},
    )

    print(experiment_id)
# Out:
# 2026/03/18 21:31:20 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/03/18 21:31:20 INFO mlflow.store.db.utils: Updating database tables
# 1
