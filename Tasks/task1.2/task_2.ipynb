# %%
#  Input Validation: Check if the input string contains exactly one "@" symbol and 
# at least one "." after the "@" symbol. If it's not a valid email, return "Invalid 
# email".

input_email=str(input("enter your email: "))
if input_email.find('@')==1:
    print("valid email")
else:
    print("invalid email")
# Out:
# invalid email

# %%
#  Extract Username: Extract and return the part of the email before the "@" 
# symbol.

input_email[0:input_email.index('@')]
# Out:
# 'dsnsdfi'

# %%
# Extract Domain: Extract and return the domain (the part between "@" and the 
# last "."). 

input_email[1+input_email.index('@'):input_email.index('.')]
# Out:
# 'shfbdslhb'

# %%
# task 1
#  Check for Domain Ending: Check if the email ends with ".com". If it does, 
# return "Commercial Domain". If it ends with ".edu", return "Educational Domain". 
# Otherwise, return "Other Domain". 

if input_email[input_email.index('.'):]==".com":
    print("Commercial Domain")
elif input_email[input_email.index('.'):]==".edu":
    print("Educational Domain")
else:
    print("Other Domain")
# Out:
# Other Domain

# %%
x="###!!@mocleW EPGTQ!!!6789"
x=x[x.index('m'):x.index('Q')+1].split(" ")
x=x[0][::-1]+"e "+x[1].replace("E","")
print(x)
# Out:
# Welcome PGTQ

# %%
word_1="&&&**$gnirtS PLIO!!@1234"
word=word_1[word_1.index("g"):word_1.index("!")]
print(word)
words=word[-6::-1]
print(word)
addword=word[7:].replace("I","E").replace("O","U")
print(word)
word=f"{words} {addword}"
print(word)
word_1=word
print(word_1)
# Out:
# gnirtS PLIO
# gnirtS PLIO
# gnirtS PLIO
# String PLEU
# String PLEU

# %%
A="##$$$@!yalpstcejorp EPUVT****9887"
A=A[A.index("y"):A.index("*")].split(" ")
B=A[1].replace("E","A").replace("U","O")[:]
print(B)
A=A[0][::-1]+" "+B[0:2]+B[4]+B[2:4]
print(A)
# Out:
# APOVT
# projectsplay APTOV
