# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv("Salary_Data.csv")
plt.Figure(figsize=(3,3))
sns.pairplot(df,x_vars=["YearsExperience"],y_vars=["Salary"],size=7,kind="scatter")
plt.xlabel="years"
plt.ylabel="salary"
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.2,random_state=42)

# %%
liner_model=LinearRegression()
liner_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train,y_train,color="blue")
plt.plot(x_train,liner_model.predict(x_train),color="red")

# %%
df.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
y_pred=liner_model.predict(x_test)
y_pred
# Out:
# array([123883.84904063,  74284.6721219 , 109109.62612867,  78505.87866817,
#         56344.54430023,  61621.05248307, 131270.96049661, 114386.13431151,
#         64786.95739278,  34183.20993228,  45791.52793454,  76395.27539503,
#         53178.63939052,  65842.25902935,  64786.95739278, 105943.72121896,
#         36293.81320542,  38404.41647856, 117552.03922122,  43680.9246614 ,
#         97501.30812641, 122828.54740406,  84837.68848758, 133381.56376975])
