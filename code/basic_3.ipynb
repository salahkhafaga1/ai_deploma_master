# %%
list_one=[1,2]
list_one.append(6)
print(list_one)
list_one.insert(1,5)
list_one.pop(0)
print(list_one)
list_one.pop()
print(list_one)
list_one.pop()
print(list_one)
# Out:
# [1, 2, 6]
# [5, 2, 6]
# [5, 2]
# [5]

# %%
name = input("Enter your name: ")
id=input("Enter your ID: ")
print(f"my name is{name}, my ID is {id}")

# %%
list_sort=[3,1,4,1,5,9,2]
list_sort.sort()
print(list_sort)
# Out:
# [1, 1, 2, 3, 4, 5, 9]

# %%
tuple_one=(1,2,3)
tuple_one=list(tuple_one)
tuple_one.append(4)
tuple_one=tuple(tuple_one)
print(tuple_one)

# %%
color_set={"red","green","blue"}
color_set.remove("red")
color_set

# %%
dict_one={"name":"Alice","age":30}
type(dict_one)

# %%
x=56
result="even" if x%2==0 else "odd"
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 x=[56]
# ----> 2 result="even" if x%2==0 else "odd"
#       3 result
#
# TypeError: unsupported operand type(s) for %: 'list' and 'int'

# %%
a=200
b=33
if b<a:
    print("b is greater than a")
elif a==b:
    print("a and b are equal")
else:
    print("a is greater than b")

# %%
for i in range(5):
    if i==2:
        break
    else:
        print(i)
# Out:
# 0
# 1

# %%
for i in range(5):
    if i==2:
        continue
    else:
        print(i)

# %%
for i in range(5):
    if i==2:
        pass
    else:
        print(i)

# %%
x=6
while 10>x>0:
    print(x)
    x+=1

# %%
# list delete item
#1 list.remove(item)
list_example=[10,20,30,40,50]
list_example.remove(30)

print(list_example)
#2 list.pop(index)
list_example.pop()

print(list_example)
#3 del list[index]
del list_example[0]
print(list_example)
# indexing
index_of_20=list_example.index(20)
print(index_of_20)
my_list = [1, 2, 3]
index_of_2=my_list.index(2)
print(index_of_2)
# sorting
my_list.sort()
print(my_list,list_example)
# reverse
my_list.reverse()
print(my_list)
# clear
my_list.clear()
print(my_list)
# Out:
# [10, 20, 40, 50]
# [10, 20, 40]
# [20, 40]
# 0
# 1
# [1, 2, 3] [20, 40]
# [3, 2, 1]
# []

# %%
# Tuple
tuple_one =(1,2,3,4,5.5,4.5,"amit","learning",[1,2,3], ("ml", "dl", "ds"))
# عايز تعدل حولها للlistو بعدين ارجعها تاني tuple
tuple_to_list=list(tuple_one)
tuple_to_list[0]=100
tuple_to_list=tuple(tuple_to_list)
print(tuple_to_list)

# %%
# Set
set_one={1,2,3,4,5,5,4,3,2,1,"amit","learning"}
# 1. Set can be represented by { }
# 2. Unordered
# 3. No Duplicates
# 4. Mutable
# 5. Can not be nested among all 
# 6. Convert any datatype to list using set() function
set_to_list=list(set_one)
print(set_to_list)

# %%
# Dictionary
dict_one={"name":"Alice","age":30,"skills":["ml","dl","ds"]}
# 1. dictionary can be represented by { }
# 2. ordered 
# 3. changeable Data
# 4. allow Duplicate Data as value not as a key

# %%
# > Greaterthan (If left > right hence return true) a > b
# < Less than (ifleft < right hence return true) a < b
# == Equal to (if left equals right return true) a == b
# != Not equalto (ifleftnot equals rightreturn true) a != b
# >= Greaterthan or equal (if left GTEright returntrue) a >= b
# <= Less than or equal (ifleft LE right return True) a <= b

# %%
x = 5
y = 10
if x>0 and y >0:
    print(f"Both {x} and {y} are positive.")

# %%
# ShortHand If - Condition
x = 5
result = "Even" if x % 20 else "Odd"
print(result)

# %%
# Nested If - Condition
is_sunny = True
temperature = 25
if is_sunny:
    print("It's a sunny day!")
    if temperature > 20:
        print("The weather is warm.")
    else:
        print("The weather is cool.")
else:
    print("It's not a sunny day.")

# %%
# LOOPS
# Loops in Python enable the repeated execution of code, with 'for' loops iterating over sequences and 'while' loops executing as long as a specified condition holds. They streamline the handling of repetitive tasks in Python programs.

# %%
# for loop
# for loop in Python is a control flow statement used for iterating over a sequence (such as a list,tuple, string, or range), executing a block of code for each element in the sequence
for x in "amit":
    print(x)
else:
    print('loop ended')

# %%
# while loop
# while loop in Python is a control flow statement that repeatedly executes a block of code as long as a specified condition remains true.

# %%
x = 6
while x > -4 :
   print(x)
   x-=1
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0
# -1
# -2
# -3
