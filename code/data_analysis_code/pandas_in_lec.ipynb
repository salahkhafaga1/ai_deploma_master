# %%
import pandas as pd

# %%
s=pd.Series([1,3,5,7,9],index=['a','b','c','d','e'])
print(s)
# Out:
# a    1
# b    3
# c    5
# d    7
# e    9
# dtype: int64

# %%
data=[[1,2,3],[4,5,6],[7,8,9]]
df=pd.DataFrame(data,columns=['col1','col2','col3'])
print(df)
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %%
data_1={'Name':['Alice','Bob','Charlie','David'],
        'Age':[25,30,35,50],}
df_1=pd.DataFrame(data_1)
print(df_1) 
df_1.columns
index=['row1','row2','row3','row4']
df_1.index=index
print(df_1)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   50
#          Name  Age
# row1    Alice   25
# row2      Bob   30
# row3  Charlie   35
# row4    David   50

# %%
# perurity
# o,s,int,float

# %%
class person():
    pass

# %%
df_1['Age'].dtype
df_1['Age']=df_1['Age'].astype('category')
df_1['Age'].dtype
# Out:
# CategoricalDtype(categories=[25, 30, 35, 50], ordered=False, categories_dtype=int64)

# %%
df_1.head()
df_1.info()
df_1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, row1 to row4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      category
# dtypes: category(1), object(1)
# memory usage: 272.0+ bytes
#          Name  Age
# count       4    4
# unique      4    4
# top     Alice   25
# freq        1    1

# %%
x=df['col1'].unique().sum()
df['col1'].min()
df['col1'].max()
df.col1.mean()
df.col1.median()
df.col1.std()
df.col1.describe()
df.col1.value_counts()
df.col1.idxmin()
df.col1.idxmax()
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    3 non-null      int64
#  1   col2    3 non-null      int64
#  2   col3    3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0 bytes

# %%
df['col1'].value_counts()
df['col1'].nunique()
df['col1'].sum()
df['col1'].mean()
# Out:
# np.float64(4.0)

# %%
df['col1'].apply(lambda x:x*2)
# Out:
# 0     2
# 1     8
# 2    14
# Name: col1, dtype: int64

# %%
df['col1'].iloc[2,1]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df['col1'].iloc[2,1]
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# ...

# %%
df.iloc[:]
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %%
df.iloc[:,0:2]
# Out:
#    col1  col2
# 0     1     2
# 1     4     5
# 2     7     8

# %%
df['col4']=df['col1']+df['col2']
df
# Out:
#    col1  col2  col3  col4
# 0     1     2     3     3
# 1     4     5     6     9
# 2     7     8     9    15

# %%
# df.drop('col4',axis=1)
df
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %%
null=df.isnull()
null.sum()
# Out:
# col1    0
# col2    0
# col3    0
# dtype: int64

# %%
pd.DataFrame(null).T
# Out:
#           0      1      2
# col1  False  False  False
# col2  False  False  False
# col3  False  False  False

# %%
def isnull_count(df):
    null=df.isnull()
    return pd.DataFrame(null).T
isnull_count(df)
# Out:
#           0      1      2
# col1  False  False  False
# col2  False  False  False
# col3  False  False  False

# %%
from p import isnull_count
isnull_count(df)
# Out:
#           0      1      2
# col1  False  False  False
# col2  False  False  False
# col3  False  False  False

# %%
df=pd.read_csv('D:/ai_deploma_master/ai_deploma_master/code/files/train (2).csv')

# %%
df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1,inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
dtypes=df.dtypes
n_unique=df.nunique()
pd.DataFrame({'dtypes':dtypes,'n_unique':n_unique}).T
# print(dtypes)
# print(n_unique)
# Out:
#          Survived Pclass     Sex      Age  SibSp  Parch     Fare Embarked
# dtypes      int64  int64  object  float64  int64  int64  float64   object
# n_unique        2      3       2       88      7      7      248        3

# %%
from p import chk_type
chk_type(df)
# Out:
#          Survived Pclass     Sex      Age  SibSp  Parch     Fare Embarked
# dtypes      int64  int64  object  float64  int64  int64  float64   object
# n_unique        2      3       2       88      7      7      248        3

# %%
cols=['Survived','Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']
df[cols]=df[cols].astype('category')

# %%
from p import convert_to_category
convert_to_category()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from p import convert_to_category
#       2 convert_to_category()
#
# File d:\ai_deploma_master\ai_deploma_master\code\p.py:21
#      17 def convert_to_category(cols):
#      18     df[cols] = df[cols].astype('category')
# ---> 21 convert_to_category(cols)
#      22 # ------------------
#      23 def reshape_vector_to_matrix(vec):
#
# NameError: name 'cols' is not defined

# %%
null=df.isnull().sum()
null
ratio=null/df.shape[0]
ratio
pd.DataFrame({'null':null,'ratio':ratio}).T
# Out:
#        Survived  Pclass  Sex         Age  SibSp  Parch  Fare  Embarked
# null        0.0     0.0  0.0  177.000000    0.0    0.0   0.0  2.000000
# ratio       0.0     0.0  0.0    0.198653    0.0    0.0   0.0  0.002245

# %%
df=df.dropna(subset=['Embarked'])
median=df['Age'].median()
df['Age'].fillna(median,inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1136\3191882983.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(median,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
# The Interquartile Range (IQR) is a robust statistical measure used primarily for Data Preprocessing and Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object

# %%
num_cols=df.select_dtypes('float').columns
plt.figure(figsize=(8,1))
for i,col in enumerate(num_cols):
    plt.subplot(1,len(num_cols),i+1)
    # sns.boxplot(df[col],orient='h')
    plt.hist(df[col])
    plt.title(f"{col} boxplot")

# %%
for col in num_cols:
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1
    lower_Fence=Q1-1.5*IQR
    upper_Fence=Q3+1.5*IQR
    lower_outliers=df[df[col]<lower_Fence][col].values
    upper_outliers=df[df[col]>upper_Fence][col].values
    df[col].replace(lower_outliers,lower_Fence,inplace=True)
    df[col].replace(upper_outliers,upper_Fence,inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1136\1446360308.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace(lower_outliers,lower_Fence,inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1136\1446360308.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
