# %%
# 1- Introduction to Functions in Python Programming.

# %%
'''  
2- Types of Functions
 1-Built-In Functions
    Examples:
     Print() , id() , abs()
2-User Defined Functions
    1-using lambda function
    2-using def function




'''

# %%
'''   
1- Built-In Functions:A built-in function in Python is a predefined and integral function inherent to the language. These functions, covering 
various tasks like math, string manipulation, and list handling, are readily available for use without explicit declaration 
or external libraries, enhancing the language's versatility and efficiency.
a-Numeric Functions
    Examples: abs() , round() , pow() , max() , min()
b-String Functions
    Examples: len() , str()  , UPPER() , lower()

c- input/output Functions
    Examples: print() , input() , format()


'''

# %%
'''
2- User Defined Functions: A user-defined function in Python is a custom function created by programmers to encapsulate specific tasks or
operations. Defined using the def keyword, these functions allow for code reuse, modularity, and  
a- using def function: functions that you use to organize your code in the body of a policy. Once you define a function, you can call it in the 
same way as the built-in action and parser functions.
'''
def function():
    
    print("hello World")
function()
# Out:
# hello World

# %%
def function_1(x,y):
     return f"the fridt number {x}, the second number {y}"
function_1(5,6)
# Out:
# 'the fridt number 5, the second number 6'

# %%
'''  
Types of Functions
1-positional Arguments: arguments are matched based on their 
                        position in the function call. The order and number of arguments matter.
2-kewword Argrument:Arguments are passed to the function using the parameter names, allowing you 
                    to specify which argument corresponds to which parameter.
3-Default Arguments:These are parameters that assume a default value if a value is not provided in the function call for that parameter.
                    varaic Arguments:The function can accept a variable number of arguments and store them 
                    as a tuple
kwargs: The function can accept a variable number of keyword arguments and store them as a dictionary.
'''

# %%
# Positional Argument Function
def f1(name, age):
    return f"Hello {name}, your age is {age}"
f1("Alice", 30)  # Correct usage
# Keyword Argument Function
f1(age=30, name="Alice")  # Also correct usage
# f1(30, "Alice")  # Incorrect usage, would lead to wrong output
# Default Argument Function
def f2(name, age=25):
    return f"Hello {name}, your age is {age}"
f2("Bob")  # Uses default age
f2("Bob", 30)  # Overrides default age
# Out:
# 'Hello Bob, your age is 30'

# %%
# varaic Argument Function
''' 
When a function has a parameter preceded by an asterisk ( * ), it can accept a variable number of arguments. 
And you can pass zero, one, or more arguments to the *args parameter.
In Python, the parameters like *args are called variadic parameters and store them as a tuple.
'''
x=10
def f_2(*name):
    return name
    print(type(name))
f_2("Alice", "Bob", "Charlie",0,True,x)
# Out:
# ('Alice', 'Bob', 'Charlie', 0, True, 10)

# %%
# Kwargs Argument Function
''' 
special syntax that allows you to pass a keyworded, variable-length argument dictionary to a function.
The function can accept a number of arguments and store them as a dictionary 

'''
def f_3(**name_1):
    print(type(name_1)) 
    return name_1
    
      
f_3(name1="Alice", name2="Bob", name3="Charlie")
# Out:
# <class 'dict'>
# {'name1': 'Alice', 'name2': 'Bob', 'name3': 'Charlie'}

# %%
# 6- User Defined Function (lambda)
'''  
A lambda function is a small anonymous function. It can take any number of arguments, but can only have 
one expression
'''
function_name=lambda x: x+10
print(function_name(5))  # Output: 15
#  --- IGNORE ---
function_name_1=lambda x,y: x*y
print(function_name_1(5,6))  # Output: 30
# Out:
# 15
# 30
