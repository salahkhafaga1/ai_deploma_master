# %%
x = 30
'''
working with strings
'''
print("my age is")
# Out:
# my age is

# %%
name = "Salah"
age = 24
course = "Machine Learning"
print("My name is {0}, I am {1} years old,I am engaged in learning {2}" . format(name, age, course))
# Out:
# My name is Salah, I am 24 years old,I am engaged in learning Machine Learning

# %%
name = "depi learning"
upper_txt=name.upper()
upper_txt
lower_txt= name.lower()
lower_txt=lower_txt.split()
lower_txt_1=' '.join(lower_txt)
# Out:
# ['depi', 'learning']
