# %%
with open("./Data/text_1.txt","a+") as file:
    file.write("\nThis is a new line added to the file.")
    file.seek(0)
    content = file.read()
    print(content)

# %%
name="hello world from ai deploma"
name1= name.split()[::-1]
name12= " ".join(name1)
print(name12)

# %%
import random

characters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"

x = int(input("Enter the length of the password: "))

def generate_password(x):
    password = ""
    for _ in range(x):
        password += random.choice(characters)
    return f"Generated password is: {password}"

print(generate_password(x))
# Out:
# Generated password is: Ws0JaLXR!lRHuCp@Y5q3
